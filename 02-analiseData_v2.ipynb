# %% [markdown]
# # Projeto Análise de dados com Python
#
# ### Iniciando analise de dados referente á um conjunto de dados referente à **Most Subscribed YouTube Channels disponivel em https://www.kaggle.com/datasets/surajjha101/top-youtube-channels-data**

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv('./most_subscribed_youtube_channels.csv')

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
#              category  started
# ...

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  video count  \
# 0     1                    T-Series    222000000  198459090822        17317
# 1     2              YouTube Movies    154000000             0            0
# 2     3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3     4                   SET India    139000000  125764252686        91271
# 4     5                       Music    116000000             0            0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4               NaN     2013

# %%
df.describe()
# Out:
#               rank   subscribers   video views    video count      started
# count  1000.000000  1.000000e+03  1.000000e+03    1000.000000  1000.000000
# mean    500.500000  2.051940e+07  9.197025e+09    7782.567000  2012.376000
# std     288.819436  1.578167e+07  1.207128e+10   28143.705441     3.998076
# min       1.000000  1.090000e+07  0.000000e+00       0.000000  1970.000000
# 25%     250.750000  1.260000e+07  3.582208e+09     293.250000  2010.000000
# 50%     500.500000  1.550000e+07  6.116574e+09     710.500000  2013.000000
# 75%     750.250000  2.210000e+07  1.124951e+10    2527.750000  2015.000000
# max    1000.000000  2.220000e+08  1.984591e+11  329711.000000  2021.000000

# %% [markdown]
# ### Tarefa
#
# Analisar os dados importados. Verificar os tipo d cada coluna e fazer os ajustes necessários. Verificar se existem dados duplicados, ausentes, etc, e realizar o tratamento caso seja necessário.

# %%
df.isnull()
# Out:
#       rank  Youtuber  subscribers  video views  video count  category  started
# 0    False     False        False        False        False     False    False
# 1    False     False        False        False        False     False    False
# 2    False     False        False        False        False     False    False
# 3    False     False        False        False        False     False    False
# 4    False     False        False        False        False      True    False
# ..     ...       ...          ...          ...          ...       ...      ...
# 995  False     False        False        False        False     False    False
# 996  False     False        False        False        False     False    False
# 997  False     False        False        False        False     False    False
# 998  False     False        False        False        False     False    False
# 999  False     False        False        False        False     False    False
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Colunas onde se encontram os NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1000 non-null   int64
#  1   Youtuber     1000 non-null   object
#  2   subscribers  1000 non-null   int64
#  3   video views  1000 non-null   int64
#  4   video count  1000 non-null   int64
#  5   category     973 non-null    object
#  6   started      1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
df[df['category'].isnull()]
# Out:
#      rank            Youtuber  subscribers  video views  video count category  \
# 4       5               Music    116000000            0            0      NaN
# 9      10              Gaming     92700000            0            0      NaN
# 15     16              Sports     75100000            0            0      NaN
# 81     82                News     36200000            0            0      NaN
# 137   138  Popular on YouTube     29400000            0            0      NaN
# ..    ...                 ...          ...          ...          ...      ...
# 863   864          WiederDude     11800000   2190306341          259      NaN
# 960   961       Влад и Никита     11100000   6761739774          396      NaN
# 966   967  Diana and Roma IND     11100000   4802776148          446      NaN
# 977   978            TV Shows     11000000            0            0      NaN
# 984   985    Wolfoo's stories     11000000   4227479765          942      NaN
#
#      started
# 4       2013
# ...

# %%
#df["category"] = df["category"].str.replace("NaN", "Não Informado", case=False)

# %%
#filter = df["category"] == "Não Informado"
#df

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'video count',
#        'category', 'started'],
#       dtype='object')

# %% [markdown]
# ## Trocamos NaN para Não informado

# %%
df.fillna('Não Informado', inplace=True)
df
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
#              category  started
# ...

# %% [markdown]
# ### Filtrando coluna por determinado conteúdo

# %%
df[df.category=="Não Informado"]
# Out:
#      rank            Youtuber  subscribers  video views  video count  \
# 4       5               Music    116000000            0            0
# 9      10              Gaming     92700000            0            0
# 15     16              Sports     75100000            0            0
# 81     82                News     36200000            0            0
# 137   138  Popular on YouTube     29400000            0            0
# ..    ...                 ...          ...          ...          ...
# 863   864          WiederDude     11800000   2190306341          259
# 960   961       Влад и Никита     11100000   6761739774          396
# 966   967  Diana and Roma IND     11100000   4802776148          446
# 977   978            TV Shows     11000000            0            0
# 984   985    Wolfoo's stories     11000000   4227479765          942
#
#           category  started
# 4    Não Informado     2013
# 9    Não Informado     2013
# 15   Não Informado     2013
# ...

# %% [markdown]
# ### Verificando se está null, vazio ou se tem dados duplicados

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# rank   Youtuber  subscribers  video views  video count  category  started
# False  False     False        False        False        False     False      1000
# dtype: int64

# %%
df.isna().value_counts()
# Out:
# rank   Youtuber  subscribers  video views  video count  category  started
# False  False     False        False        False        False     False      1000
# dtype: int64

# %%
 df.to_pickle("arquivo_tratamento_01.pkl")
# df = pd.read_pickle("arquivo_tratamento_01.pkl")

# %%
pd.options.display.float_format = '{:20, .2f}'.format

# %%
df = pd.read_pickle("arquivo_tratamento_01.pkl")
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  video count  \
# 0     1                    T-Series    222000000  198459090822        17317
# 1     2              YouTube Movies    154000000             0            0
# 2     3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3     4                   SET India    139000000  125764252686        91271
# 4     5                       Music    116000000             0            0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Não Informado     2013

# %%
#%matplotlib inline

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'video count',
#        'category', 'started'],
#       dtype='object')

# %%
df.dtypes
# Out:
# rank            int64
# Youtuber       object
# subscribers     int64
# video views     int64
# video count     int64
# category       object
# started         int64
# dtype: object

# %%
tips = sns.load_dataset("tips")
sns.set_style("whitegrid")
g = sns.lmplot(x="tip", y="total_bill", data=tips,
 aspect=2)
g = (g.set_axis_labels("Tip","Total bill(USD)").
set(xlim=(0,15),ylim=(0,100)))

graph = sns.jointplot(x="subscribers", y="video views", data=df,
                  kind="reg", truncate=False,
                  xlim=(10000000,222000000), ylim=(0, 198459090822),
                  color="m", height=7)
