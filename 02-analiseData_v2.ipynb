# %% [markdown]
# # Projeto Análise de dados com Python
#
# ### Iniciando analise de dados referente á um conjunto de dados referente à **Most Subscribed YouTube Channels disponivel em https://www.kaggle.com/datasets/surajjha101/top-youtube-channels-data**

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv('../datascience/most_subscribed_youtube_channels.csv')

# %%
df
# Out:
#      rank                    Youtuber  subscribers      video views  \
# 0       1                    T-Series  222,000,000  198,459,090,822
# 1       2              YouTube Movies  154,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848
# 3       4                   SET India  139,000,000  125,764,252,686
# 4       5                       Music  116,000,000                0
# ..    ...                         ...          ...              ...
# 995   996                    JP Plays   10,900,000    4,609,300,218
# 996   997               TrapMusicHDTV   10,900,000    4,070,521,973
# 997   998                 Games EduUu   10,900,000    3,093,784,767
# 998   999                       Hueva   10,900,000    3,040,301,750
# 999  1000              Dobre Brothers   10,900,000    2,808,411,693
#
#     video count          category  started
# 0        17,317             Music     2006
# 1             0  Film & Animation     2015
# 2           786         Education     2006
# 3        91,271             Shows     2006
# 4             0               NaN     2013
# ..          ...               ...      ...
# 995       3,528            Gaming     2014
# 996         690             Music     2013
# 997       1,006            Gaming     2011
# 998         831            Gaming     2012
# 999         590    People & Blogs     2017
#
# [1000 rows x 7 columns]

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers      video views video count  \
# 0     1                    T-Series  222,000,000  198,459,090,822      17,317
# 1     2              YouTube Movies  154,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848         786
# 3     4                   SET India  139,000,000  125,764,252,686      91,271
# 4     5                       Music  116,000,000                0           0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4               NaN     2013

# %%
df.describe()
# Out:
#               rank      started
# count  1000.000000  1000.000000
# mean    500.500000  2012.376000
# std     288.819436     3.998076
# min       1.000000  1970.000000
# 25%     250.750000  2010.000000
# 50%     500.500000  2013.000000
# 75%     750.250000  2015.000000
# max    1000.000000  2021.000000

# %% [markdown]
# ### Tarefa
#
# Analisar os dados importados. Verificar os tipo d cada coluna e fazer os ajustes necessários. Verificar se existem dados duplicados, ausentes, etc, e realizar o tratamento caso seja necessário.

# %%
df.isnull()
# Out:
#       rank  Youtuber  subscribers  video views  video count  category  started
# 0    False     False        False        False        False     False    False
# 1    False     False        False        False        False     False    False
# 2    False     False        False        False        False     False    False
# 3    False     False        False        False        False     False    False
# 4    False     False        False        False        False      True    False
# ..     ...       ...          ...          ...          ...       ...      ...
# 995  False     False        False        False        False     False    False
# 996  False     False        False        False        False     False    False
# 997  False     False        False        False        False     False    False
# 998  False     False        False        False        False     False    False
# 999  False     False        False        False        False     False    False
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Colunas onde se encontram os NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1000 non-null   int64
#  1   Youtuber     1000 non-null   object
#  2   subscribers  1000 non-null   object
#  3   video views  1000 non-null   object
#  4   video count  1000 non-null   object
#  5   category     973 non-null    object
#  6   started      1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
df[df['category'].isnull()]
# Out:
#      rank            Youtuber  subscribers    video views video count  \
# 4       5               Music  116,000,000              0           0
# 9      10              Gaming   92,700,000              0           0
# 15     16              Sports   75,100,000              0           0
# 81     82                News   36,200,000              0           0
# 137   138  Popular on YouTube   29,400,000              0           0
# ..    ...                 ...          ...            ...         ...
# 863   864          WiederDude   11,800,000  2,190,306,341         259
# 960   961       Влад и Никита   11,100,000  6,761,739,774         396
# 966   967  Diana and Roma IND   11,100,000  4,802,776,148         446
# 977   978            TV Shows   11,000,000              0           0
# 984   985    Wolfoo's stories   11,000,000  4,227,479,765         942
#
#     category  started
# 4        NaN     2013
# 9        NaN     2013
# 15       NaN     2013
# 81       NaN     2013
# 137      NaN     2013
# ..       ...      ...
# 863      NaN     2016
# 960      NaN     2018
# 966      NaN     2019
# 977      NaN     2012
# 984      NaN     2016
#
# [27 rows x 7 columns]

# %%
#df["category"] = df["category"].str.replace("NaN", "Não Informado", case=False)

# %%
#filter = df["category"] == "Não Informado"
#df

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'video count',
#        'category', 'started'],
#       dtype='object')

# %% [markdown]
# ## Trocamos NaN para Não informado

# %%
df.fillna('Não Informado', inplace=True)
df
# Out:
#      rank                    Youtuber  subscribers      video views  \
# 0       1                    T-Series  222,000,000  198,459,090,822
# 1       2              YouTube Movies  154,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848
# 3       4                   SET India  139,000,000  125,764,252,686
# 4       5                       Music  116,000,000                0
# ..    ...                         ...          ...              ...
# 995   996                    JP Plays   10,900,000    4,609,300,218
# 996   997               TrapMusicHDTV   10,900,000    4,070,521,973
# 997   998                 Games EduUu   10,900,000    3,093,784,767
# 998   999                       Hueva   10,900,000    3,040,301,750
# 999  1000              Dobre Brothers   10,900,000    2,808,411,693
#
#     video count          category  started
# 0        17,317             Music     2006
# 1             0  Film & Animation     2015
# 2           786         Education     2006
# 3        91,271             Shows     2006
# 4             0     Não Informado     2013
# ..          ...               ...      ...
# 995       3,528            Gaming     2014
# 996         690             Music     2013
# 997       1,006            Gaming     2011
# 998         831            Gaming     2012
# 999         590    People & Blogs     2017
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Filtrando coluna por determinado conteúdo

# %%
df[df.category=="Não Informado"]
# Out:
#      rank            Youtuber  subscribers    video views video count  \
# 4       5               Music  116,000,000              0           0
# 9      10              Gaming   92,700,000              0           0
# 15     16              Sports   75,100,000              0           0
# 81     82                News   36,200,000              0           0
# 137   138  Popular on YouTube   29,400,000              0           0
# ..    ...                 ...          ...            ...         ...
# 863   864          WiederDude   11,800,000  2,190,306,341         259
# 960   961       Влад и Никита   11,100,000  6,761,739,774         396
# 966   967  Diana and Roma IND   11,100,000  4,802,776,148         446
# 977   978            TV Shows   11,000,000              0           0
# 984   985    Wolfoo's stories   11,000,000  4,227,479,765         942
#
#           category  started
# 4    Não Informado     2013
# 9    Não Informado     2013
# 15   Não Informado     2013
# 81   Não Informado     2013
# 137  Não Informado     2013
# ..             ...      ...
# 863  Não Informado     2016
# 960  Não Informado     2018
# 966  Não Informado     2019
# 977  Não Informado     2012
# 984  Não Informado     2016
#
# [27 rows x 7 columns]

# %% [markdown]
# ### Verificando se está null, vazio ou se tem dados duplicados

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# rank   Youtuber  subscribers  video views  video count  category  started
# False  False     False        False        False        False     False      1000
# dtype: int64

# %%
df.isna().value_counts()
# Out:
# rank   Youtuber  subscribers  video views  video count  category  started
# False  False     False        False        False        False     False      1000
# dtype: int64

# %%
# df.to_pickle("arquivo_tratamento_01.pkl")
# df = pd.read_pickle("arquivo_tratamento_01.pkl")

# %%
pd.options.display.float_format = '{:20, .2f}'.format

# %%
df = pd.read_pickle("arquivo_tratamento_01.pkl")
df.head()
# Out:
#    rank                    Youtuber  subscribers      video views video count  \
# 0     1                    T-Series  222,000,000  198,459,090,822      17,317
# 1     2              YouTube Movies  154,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848         786
# 3     4                   SET India  139,000,000  125,764,252,686      91,271
# 4     5                       Music  116,000,000                0           0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Não Informado     2013

# %%
#%matplotlib inline

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'video count',
#        'category', 'started'],
#       dtype='object')

# %%
graph = sns.jointplot(x="subscribers", y="video views", data=df,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'conjugate'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 graph = sns.jointplot(x="subscribers", y="video views", data=df,
#       2                   kind="reg", truncate=False,
#       3                   xlim=(0, 60), ylim=(0, 12),
#       4                   color="m", height=7)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/axisgrid.py:2313, in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2310     grid.plot_marginals(histplot, **marginal_kws)
#    2312     joint_kws.setdefault("color", color)
# -> 2313     grid.plot_joint(regplot, **joint_kws)
#    2315 elif kind.startswith("resid"):
#    2317     joint_kws.setdefault("color", color)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/axisgrid.py:1806, in JointGrid.plot_joint(self, func, **kwargs)
#    1803     self._inject_kwargs(func, kwargs, self._hue_params)
#    1805 if str(func.__module__).startswith("seaborn"):
# -> 1806     func(x=self.x, y=self.y, **kwargs)
#    1807 else:
#    1808     func(self.x, self.y, **kwargs)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:221, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     219     yhat, yhat_boots = self.fit_logx(grid)
#     220 else:
# --> 221     yhat, yhat_boots = self.fit_fast(grid)
#     223 # Compute the confidence interval at each grid point
#     224 if ci is None:
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:238, in _RegressionPlotter.fit_fast(self, grid)
#     236 X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#     237 grid = np.c_[np.ones(len(grid)), grid]
# --> 238 yhat = grid.dot(reg_func(X, y))
#     239 if self.ci is None:
#     240     return yhat, None
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/seaborn/regression.py:234, in _RegressionPlotter.fit_fast.<locals>.reg_func(_x, _y)
#     233 def reg_func(_x, _y):
# --> 234     return np.linalg.pinv(_x).dot(_y)
#
# File <__array_function__ internals>:180, in pinv(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/intro/lib/python3.10/site-packages/numpy/linalg/linalg.py:1997, in pinv(a, rcond, hermitian)
#    1995     res = empty(a.shape[:-2] + (n, m), dtype=a.dtype)
#    1996     return wrap(res)
# -> 1997 a = a.conjugate()
#    1998 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2000 # discard small singular values
#
# TypeError: loop of ufunc does not support argument 1 of type str which has no callable conjugate method
